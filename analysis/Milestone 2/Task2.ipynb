# %% [markdown]
# # Method Chaining The Analysis Pipeline

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/evanlewis/data301/Project/project-group53-project/data/raw/PRWI_Data.csv')
df
# Out:
#       Admin_Unit_Code  Sub_Unit_Code Site_Name  Plot_Name Location_Type  Year  \
# 0                PRWI            NaN    PRWI 2  PRWI-0097        Forest  2007
# 1                PRWI            NaN    PRWI 2  PRWI-0097        Forest  2007
# 2                PRWI            NaN    PRWI 2  PRWI-0097        Forest  2007
# 3                PRWI            NaN    PRWI 2  PRWI-0097        Forest  2007
# 4                PRWI            NaN    PRWI 2  PRWI-0097        Forest  2007
# ...               ...            ...       ...        ...           ...   ...
# 29106            PRWI            NaN   PRWI 22  PRWI-0728        Forest  2017
# 29107            PRWI            NaN   PRWI 22  PRWI-0728        Forest  2017
# 29108            PRWI            NaN   PRWI 22  PRWI-0728        Forest  2017
# 29109            PRWI            NaN   PRWI 22  PRWI-0728        Forest  2017
# 29110            PRWI            NaN   PRWI 22  PRWI-0728        Forest  2017
#
#              Date Start_Time End_Time         Observer  ...  NPSTaxonCode  \
# 0      2007-05-29       6:27     6:46  Desiree Narango  ...       85846.0
# 1      2007-05-29       6:27     6:46  Desiree Narango  ...       93587.0
# 2      2007-05-29       6:27     6:46  Desiree Narango  ...       95300.0
# 3      2007-05-29       6:27     6:46  Desiree Narango  ...       92689.0
# 4      2007-05-29       6:27     6:46  Desiree Narango  ...      266957.0
# ...           ...        ...      ...              ...  ...           ...
# 29106  2017-07-16       6:32     6:42    Ryan Trenkamp  ...      266957.0
# 29107  2017-07-16       6:32     6:42    Ryan Trenkamp  ...       85739.0
# 29108  2017-07-16       6:32     6:42    Ryan Trenkamp  ...       93587.0
# 29109  2017-07-16       6:32     6:42    Ryan Trenkamp  ...       87136.0
# 29110  2017-07-16       6:32     6:42    Ryan Trenkamp  ...      266957.0
#
#       AOU_Code PIF_Watchlist_Status Regional_Stewardship_Status  Temperature  \
# 0         EAWP                False                        True         18.5
# 1         REVI                False                       False         18.5
# 2         AMGO                False                       False         18.5
# 3         OVEN                False                       False         18.5
# 4         ETTI                False                       False         18.5
# ...        ...                  ...                         ...          ...
# 29106     ETTI                False                       False         21.0
# 29107     HAWO                False                       False         21.0
# 29108     REVI                False                       False         21.0
# 29109     AMRO                False                       False         21.0
# 29110     ETTI                False                       False         21.0
#
#       Humidity                  Sky                                      Wind  \
# 0         85.0        Partly Cloudy     Calm (< 1 mph) smoke rises vertically
# 1         85.0        Partly Cloudy     Calm (< 1 mph) smoke rises vertically
# 2         85.0        Partly Cloudy     Calm (< 1 mph) smoke rises vertically
# 3         85.0        Partly Cloudy     Calm (< 1 mph) smoke rises vertically
# 4         85.0        Partly Cloudy     Calm (< 1 mph) smoke rises vertically
# ...        ...                  ...                                       ...
# 29106     74.0  Clear or Few Clouds  Light breeze (4-7 mph) wind felt on face
# 29107     74.0  Clear or Few Clouds  Light breeze (4-7 mph) wind felt on face
# 29108     74.0  Clear or Few Clouds  Light breeze (4-7 mph) wind felt on face
# 29109     74.0  Clear or Few Clouds  Light breeze (4-7 mph) wind felt on face
# 29110     74.0  Clear or Few Clouds  Light breeze (4-7 mph) wind felt on face
#
#                     Disturbance  Initial_Three_Min_Cnt
# 0        Slight effect on count                  False
# 1        Slight effect on count                  False
# 2        Slight effect on count                  False
# 3        Slight effect on count                  False
# 4        Slight effect on count                  False
# ...                         ...                    ...
# 29106  Moderate effect on count                  False
# 29107  Moderate effect on count                  False
# 29108  Moderate effect on count                   True
# 29109  Moderate effect on count                   True
# 29110  Moderate effect on count                  False
#
# [29111 rows x 29 columns]

# %%
#This Method Chain is used to clean and process the data

lbls = ['Admin_Unit_Code', 'Sub_Unit_Code', 'Plot_Name', 'Location_Type', 'Date', 'Start_Time', 'End_Time', 'Observer', "Visit", 'NPSTaxonCode', "AOU_Code", 'PIF_Watchlist_Status', 'Regional_Stewardship_Status', 'Humidity', 'Sky', 'Wind', 'Initial_Three_Min_Cnt','Interval_Length','ID_Method','Distance','Flyover_Observed', 'Sex', 'Scientific_Name', 'AcceptedTSN','Disturbance']
bins = [0, 15, 20, 25, 35, np.inf]
names = ['<15', '15-20', '20-25', '25-35', '35+']
df = (
    pd.DataFrame(df.drop(labels = lbls,axis=1)
                 .rename(columns={'Site_Name':'Site','Common_Name':'Species'})
                .assign(Temp_Range=pd.cut(df['Temperature'], bins, labels=names)))
    )
df
# Out:
#           Site  Year                  Species  Temperature Temp_Range
# 0       PRWI 2  2007       Eastern Wood-Pewee         18.5      15-20
# 1       PRWI 2  2007           Red-eyed Vireo         18.5      15-20
# 2       PRWI 2  2007       American Goldfinch         18.5      15-20
# 3       PRWI 2  2007                 Ovenbird         18.5      15-20
# 4       PRWI 2  2007  Eastern Tufted Titmouse         18.5      15-20
# ...        ...   ...                      ...          ...        ...
# 29106  PRWI 22  2017  Eastern Tufted Titmouse         21.0      20-25
# 29107  PRWI 22  2017         Hairy Woodpecker         21.0      20-25
# 29108  PRWI 22  2017           Red-eyed Vireo         21.0      20-25
# 29109  PRWI 22  2017           American Robin         21.0      20-25
# 29110  PRWI 22  2017  Eastern Tufted Titmouse         21.0      20-25
#
# [29111 rows x 5 columns]

# %%
# Now I'll put that chain into a function to be used in the future, and save it in the project_function.py file 

def clean_and_process(path):
    
    import numpy as np 
    import pandas as pd 
    
    df = (pd.read_csv(path))
    
    bins = [0, 10, 20, 30, 40, np.inf]
    names = ['<15', '15-20', '20-25', '25-35', '35+']
    lbls = ['Admin_Unit_Code', 'Sub_Unit_Code', 'Plot_Name', 'Location_Type', 'Date', 'Start_Time', 'End_Time', 'Observer', "Visit", 'NPSTaxonCode', "AOU_Code", 'PIF_Watchlist_Status', 'Regional_Stewardship_Status', 'Humidity', 'Sky', 'Wind', 'Initial_Three_Min_Cnt','Interval_Length','ID_Method','Distance','Flyover_Observed', 'Sex', 'Scientific_Name', 'AcceptedTSN','Disturbance']
    
    df_clean = (
        df.drop(labels = lbls,axis=1)
        .rename(columns={'Site_Name':'Site','Common_Name':'Species'})
        .assign(Temp_Range=pd.cut(df['Temperature'], bins, labels=names))
    )
    
    return df_clean
