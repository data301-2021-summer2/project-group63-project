# %%
import pandas as pd

# %%
print (pd)
# Out:
# <module 'pandas' from '/Users/evanlewis/opt/miniconda3/lib/python3.8/site-packages/pandas/__init__.py'>

# %%
print(pd.version)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-30927ea06b88> in <module>
# ----> 1 print(pd.version)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'version'

# %%
print(pd.__version__)
# Out:
# 1.2.5

# %%
pd.read_csv('/Users/evanlewis/data301/Project/project-group53-project/data/raw/NCRN_bird_data.csv')
# Out:
#     Admin_Unit_Code  Sub_Unit_Code Site_Name  Plot_Name Location_Type  Year  \
# 0              WOTR            NaN      WOTR  WOTR-0003        Forest  2016
# 1              WOTR            NaN      WOTR  WOTR-0003        Forest  2016
# 2              WOTR            NaN      WOTR  WOTR-0003        Forest  2016
# 3              WOTR            NaN      WOTR  WOTR-0003        Forest  2016
# 4              WOTR            NaN      WOTR  WOTR-0003        Forest  2016
# ..              ...            ...       ...        ...           ...   ...
# 652            WOTR            NaN      WOTR  WOTR-0007        Forest  2014
# 653            WOTR            NaN      WOTR  WOTR-0007        Forest  2014
# 654            WOTR            NaN      WOTR  WOTR-0007        Forest  2014
# 655            WOTR            NaN      WOTR  WOTR-0007        Forest  2014
# 656            WOTR            NaN      WOTR  WOTR-0007        Forest  2014
#
# ...
